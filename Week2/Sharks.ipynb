# %%
conda install -c conda-forge xlrd>=2.0.1
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 200 None
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Saul\Downloads\GSAF5.xls")
print (df)
# Out:
#              Date    Year          Type    Country            State  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 1     13 Oct-2023  2023.0  Questionable        USA       California
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California
# ...           ...     ...           ...        ...              ...
# 6926          NaN     NaN           NaN        NaN              NaN
# 6927          NaN     NaN           NaN        NaN              NaN
# 6928          NaN     NaN           NaN        NaN              NaN
# 6929          NaN     NaN           NaN        NaN              NaN
# 6930          NaN     NaN           NaN        NaN              NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Date, Year, Type, Country, State, Location, Activity, Name, Sex, Age, Injury, Unnamed: 11, Time, Species , Source, pdf, href formula, href, Case Number, Case Number.1, original order, Unnamed: 21, Unnamed: 22]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.isnull()
# Out:
#        Date   Year   Type  Country  State  Location  Activity   Name    Sex  \
# 0     False  False  False    False  False     False     False  False  False
# 1     False  False  False    False  False     False     False  False  False
# 2     False  False  False    False  False     False     False  False  False
# 3     False  False  False    False  False     False     False  False  False
# 4     False  False  False    False  False     False     False  False  False
# ...     ...    ...    ...      ...    ...       ...       ...    ...    ...
# 6926   True   True   True     True   True      True      True   True   True
# 6927   True   True   True     True   True      True      True   True   True
# 6928   True   True   True     True   True      True      True   True   True
# 6929   True   True   True     True   True      True      True   True   True
# 6930   True   True   True     True   True      True      True   True   True
#
# ...

# %%
df.isna().sum()
# Out:
# Date                25
# Year                27
# Type                43
# Country             75
# State              506
# Location           589
# Activity           609
# Name               244
# Sex                604
# Age               3011
# Injury              60
# Unnamed: 11        587
# Time              3543
# Species           3145
# Source              44
# pdf                132
# href formula       112
# href               135
# Case Number        133
# Case Number.1      134
# original order     132
# Unnamed: 21       6930
# Unnamed: 22       6929
# dtype: int64

# %%
df.drop(['Date'], axis=1)
# Out:
#         Year          Type    Country            State  \
# 0     2023.0    Unprovoked        USA           Hawaii
# 1     2023.0  Questionable        USA       California
# 2     2023.0    Unprovoked        USA           Hawaii
# 3     2023.0    Unprovoked  AUSTRALIA  South Australia
# 4     2023.0    Unprovoked        USA       California
# ...      ...           ...        ...              ...
# 6926     NaN           NaN        NaN              NaN
# 6927     NaN           NaN        NaN              NaN
# 6928     NaN           NaN        NaN              NaN
# 6929     NaN           NaN        NaN              NaN
# 6930     NaN           NaN        NaN              NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# ...

# %%
df.drop(columns=['Source', 'State'])
# Out:
#              Date    Year          Type    Country  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA
# 1     13 Oct-2023  2023.0  Questionable        USA
# 2     02 Oct-2023  2023.0    Unprovoked        USA
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA
# 4     01 Oct-2023  2023.0    Unprovoked        USA
# ...           ...     ...           ...        ...
# 6926          NaN     NaN           NaN        NaN
# 6927          NaN     NaN           NaN        NaN
# 6928          NaN     NaN           NaN        NaN
# 6929          NaN     NaN           NaN        NaN
# 6930          NaN     NaN           NaN        NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# 3                                            Beachport  Swimming
# ...

# %%
df.drop(columns=['Location', 'Name'], inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Activity', 'Sex', 'Age',
#        'Injury', 'Unnamed: 11', 'Time', 'Species ', 'Source', 'pdf',
#        'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
df.drop (columns=["href", "Case Number","href formula", "Case Number" ], inplace=True)
df
# Out:
#              Date    Year          Type    Country            State  Activity  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 1     13 Oct-2023  2023.0  Questionable        USA       California   Surfing
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia  Swimming
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California  Swimming
# ...           ...     ...           ...        ...              ...       ...
# 6926          NaN     NaN           NaN        NaN              NaN       NaN
# 6927          NaN     NaN           NaN        NaN              NaN       NaN
# 6928          NaN     NaN           NaN        NaN              NaN       NaN
# 6929          NaN     NaN           NaN        NaN              NaN       NaN
# 6930          NaN     NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
df.drop (columns=["Source", "pdf","Case Number.1", "original order", "Unnamed: 21", "Unnamed: 22"], inplace=True)
df
# Out:
#              Date    Year          Type    Country            State  Activity  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 1     13 Oct-2023  2023.0  Questionable        USA       California   Surfing
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia  Swimming
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California  Swimming
# ...           ...     ...           ...        ...              ...       ...
# 6926          NaN     NaN           NaN        NaN              NaN       NaN
# 6927          NaN     NaN           NaN        NaN              NaN       NaN
# 6928          NaN     NaN           NaN        NaN              NaN       NaN
# 6929          NaN     NaN           NaN        NaN              NaN       NaN
# 6930          NaN     NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
df.drop (columns=[ "Unnamed: 11"], inplace=True)
df
# Out:
#              Date    Year          Type    Country            State  Activity  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 1     13 Oct-2023  2023.0  Questionable        USA       California   Surfing
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia  Swimming
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California  Swimming
# ...           ...     ...           ...        ...              ...       ...
# 6926          NaN     NaN           NaN        NaN              NaN       NaN
# 6927          NaN     NaN           NaN        NaN              NaN       NaN
# 6928          NaN     NaN           NaN        NaN              NaN       NaN
# 6929          NaN     NaN           NaN        NaN              NaN       NaN
# 6930          NaN     NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
# We found that Species had a blank space at the end, but we dropped it.
df.drop (columns=[ "Species "], inplace=True)
df
# Out:
#              Date    Year          Type    Country            State  Activity  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 1     13 Oct-2023  2023.0  Questionable        USA       California   Surfing
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii   Surfing
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia  Swimming
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California  Swimming
# ...           ...     ...           ...        ...              ...       ...
# 6926          NaN     NaN           NaN        NaN              NaN       NaN
# 6927          NaN     NaN           NaN        NaN              NaN       NaN
# 6928          NaN     NaN           NaN        NaN              NaN       NaN
# 6929          NaN     NaN           NaN        NaN              NaN       NaN
# 6930          NaN     NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
df.isna().sum()
# Out:
# Date          25
# Year          27
# Type          43
# Country       75
# State        506
# Activity     609
# Sex          604
# Age         3011
# Injury        60
# Time        3543
# dtype: int64

# %%
df.drop (columns=[ "State", "Time"], inplace=True)
df
# Out:
#              Date    Year          Type    Country  Activity  Sex  Age  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA   Surfing    M   50
# 1     13 Oct-2023  2023.0  Questionable        USA   Surfing    M   52
# 2     02 Oct-2023  2023.0    Unprovoked        USA   Surfing    F   45
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  Swimming    F   64
# 4     01 Oct-2023  2023.0    Unprovoked        USA  Swimming    M   52
# ...           ...     ...           ...        ...       ...  ...  ...
# 6926          NaN     NaN           NaN        NaN       NaN  NaN  NaN
# 6927          NaN     NaN           NaN        NaN       NaN  NaN  NaN
# 6928          NaN     NaN           NaN        NaN       NaN  NaN  NaN
# 6929          NaN     NaN           NaN        NaN       NaN  NaN  NaN
# 6930          NaN     NaN           NaN        NaN       NaN  NaN  NaN
#
#                                  Injury
# 0             Left leg and hand injured
# ...

# %%
df.isna().sum()
# Out:
# Date          25
# Year          27
# Type          43
# Country       75
# Activity     609
# Sex          604
# Age         3011
# Injury        60
# dtype: int64

# %%
# df.dropna(axis=0, subset=['Age'])?

#Should we fill the age with the mean?
#Should we fill the year and date with forward or backwards?
#Should we filter with Injurrys fatal?
#Should we 

df[df['Injury'].str.contains("FATAL")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 8
#       1 # df.dropna(axis=0, subset=['Age'])?
#       2
#       3 #Should we fill the age with the mean?
#       4 #Should we fill the year and date with forward or backwards?
#       5 #Should we filter with Injurrys fatal?
#       6 #Should we
# ----> 8 df[df['Injury'].str.contains("FATAL")]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
# ...

# %%
#We delete null values in column Injury in order to filter for FATAL injuries.

df.dropna(subset=['Injury'], inplace=True)

# %%
df.isna().sum()
# Out:
# Date           0
# Year           2
# Type          18
# Country       48
# Activity     568
# Sex          564
# Age         2958
# Injury         0
# dtype: int64

# %%
df
# Out:
#              Date    Year          Type             Country      Activity Sex  \
# 0     15 Oct-2023  2023.0    Unprovoked                 USA       Surfing   M
# 1     13 Oct-2023  2023.0  Questionable                 USA       Surfing   M
# 2     02 Oct-2023  2023.0    Unprovoked                 USA       Surfing   F
# 3     01 Oct-2023  2023.0    Unprovoked           AUSTRALIA      Swimming   F
# 4     01 Oct-2023  2023.0    Unprovoked                 USA      Swimming   M
# ...           ...     ...           ...                 ...           ...  ..
# 6901  Before 1903     0.0    Unprovoked           AUSTRALIA        Diving   M
# 6902  Before 1903     0.0    Unprovoked           AUSTRALIA  Pearl diving   M
# 6903    1900-1905     0.0    Unprovoked                 USA      Swimming   M
# 6904    1883-1889     0.0    Unprovoked              PANAMA           NaN   M
# 6905    1845-1853     0.0    Unprovoked  CEYLON (SRI LANKA)      Swimming   M
#
# ...

# %%
#We just want to focus on the worst type of injuries--> FATAL NOT IN PLACE FOR NOW
df[df['Injury'].str.contains("FATAL")]
# Out:
#              Date    Year        Type             Country      Activity Sex  \
# 49    13-May-2023  2023.0  Unprovoked           AUSTRALIA       Surfing   M
# 71    19-Feb-2023  2023.0  Unprovoked       NEW CALEDONIA      Swimming   M
# 102   25-Sep-2022  2022.0  Unprovoked        SOUTH AFRICA      Swimming   F
# 104   06-Sep-2022  2022.0  Unprovoked             BAHAMAS    Snorkeling   F
# 125   04-Jul-2022  2022.0  Unprovoked               JAPAN    Snorkeling   M
# ...           ...     ...         ...                 ...           ...  ..
# 6901  Before 1903     0.0  Unprovoked           AUSTRALIA        Diving   M
# 6902  Before 1903     0.0  Unprovoked           AUSTRALIA  Pearl diving   M
# 6903    1900-1905     0.0  Unprovoked                 USA      Swimming   M
# 6904    1883-1889     0.0  Unprovoked              PANAMA           NaN   M
# 6905    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)      Swimming   M
#
# ...

# %%
# Age: Filling null values with mean.
# Sex: Dropping null rows since it is less than 10% of the whole database.
df.duplicated().sum()
# Out:
# 10

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#              Date    Year          Type             Country      Activity Sex  \
# 0     15 Oct-2023  2023.0    Unprovoked                 USA       Surfing   M
# 1     13 Oct-2023  2023.0  Questionable                 USA       Surfing   M
# 2     02 Oct-2023  2023.0    Unprovoked                 USA       Surfing   F
# 3     01 Oct-2023  2023.0    Unprovoked           AUSTRALIA      Swimming   F
# 4     01 Oct-2023  2023.0    Unprovoked                 USA      Swimming   M
# ...           ...     ...           ...                 ...           ...  ..
# 6901  Before 1903     0.0    Unprovoked           AUSTRALIA        Diving   M
# 6902  Before 1903     0.0    Unprovoked           AUSTRALIA  Pearl diving   M
# 6903    1900-1905     0.0    Unprovoked                 USA      Swimming   M
# 6904    1883-1889     0.0    Unprovoked              PANAMA           NaN   M
# 6905    1845-1853     0.0    Unprovoked  CEYLON (SRI LANKA)      Swimming   M
#
# ...

# %%
df= df.reset_index()
df
# Out:
#       index         Date    Year          Type             Country  \
# 0         0  15 Oct-2023  2023.0    Unprovoked                 USA
# 1         1  13 Oct-2023  2023.0  Questionable                 USA
# 2         2  02 Oct-2023  2023.0    Unprovoked                 USA
# 3         3  01 Oct-2023  2023.0    Unprovoked           AUSTRALIA
# 4         4  01 Oct-2023  2023.0    Unprovoked                 USA
# ...     ...          ...     ...           ...                 ...
# 6856   6901  Before 1903     0.0    Unprovoked           AUSTRALIA
# 6857   6902  Before 1903     0.0    Unprovoked           AUSTRALIA
# 6858   6903    1900-1905     0.0    Unprovoked                 USA
# 6859   6904    1883-1889     0.0    Unprovoked              PANAMA
# 6860   6905    1845-1853     0.0    Unprovoked  CEYLON (SRI LANKA)
#
#           Activity Sex  Age                                             Injury
# 0          Surfing   M   50                          Left leg and hand injured
# ...

# %%
# We will tackle the top 5 countries with 
df['Country'].value_counts()
# Out:
# USA                   2525
# AUSTRALIA             1457
# SOUTH AFRICA           595
# NEW ZEALAND            140
# PAPUA NEW GUINEA       136
#                       ...
# ST. MARTIN               1
# RED SEA                  1
# TURKS and CaICOS         1
# MeXICO                   1
# CEYLON (SRI LANKA)       1
# Name: Country, Length: 222, dtype: int64

# %%
import seaborn as sns

# %%
df['Year'].unique()
# Out:
# array([2023., 2022., 2021., 2020., 2019., 2018., 2017.,   nan, 2016.,
#        2015., 2014., 2013., 2012., 2011., 2010., 2009., 2008., 2007.,
#        2006., 2005., 2004., 2003., 2002., 2001., 2000., 1999., 1998.,
#        1997., 1996., 1995., 1984., 1994., 1993., 1992., 1991., 1990.,
#        1989., 1969., 1988., 1987., 1986., 1985., 1983., 1982., 1981.,
#        1980., 1979., 1978., 1977., 1976., 1975., 1974., 1973., 1972.,
#        1971., 1970., 1968., 1967., 1966., 1965., 1964., 1963., 1962.,
#        1961., 1960., 1959., 1958., 1957., 1956., 1955., 1954., 1953.,
#        1952., 1951., 1950., 1949., 1948., 1848., 1947., 1946., 1945.,
#        1944., 1943., 1942., 1941., 1940., 1939., 1938., 1937., 1936.,
#        1935., 1934., 1933., 1932., 1931., 1930., 1929., 1928., 1927.,
#        1926., 1925., 1924., 1923., 1922., 1921., 1920., 1919., 1918.,
#        1917., 1916., 1915., 1914., 1913., 1912., 1911., 1910., 1909.,
# ...

# %%
df.dtypes
# Out:
# index         int64
# Date         object
# Year        float64
# Type         object
# Country      object
# Activity     object
# Sex          object
# Age          object
# Injury       object
# dtype: object

# %%
df_past_years= df[df['Year'].between(2012.0,2022.0)][['Date','Year','Type', 'Country', 'Activity','Sex','Age','Injury']]
df_past_years
# Out:
#              Date    Year        Type       Country              Activity Sex  \
# 81    30-Dec-2022  2022.0    Provoked  South Africa  Diving/Shark Feeding   M
# 82    13-Dec-2022  2022.0  Unprovoked           USA              Swimming   M
# 83    11 Dec-2022  2022.0  Unprovoked     AUSTRALIA              Swimming   M
# 84    09-Dec-2022  2022.0  Unprovoked           USA                Diving   M
# 85    08-Dec-2022  2022.0  Unprovoked           USA            Snorkeling   F
# ...           ...     ...         ...           ...                   ...  ..
# 1395  18-Jan-2012  2012.0  Unprovoked     AUSTRALIA               Surfing   M
# 1396  15-Jan-2012  2012.0  Unprovoked  SOUTH AFRICA              Swimming   M
# 1397  13-Jan-2012  2012.0  Unprovoked           USA               Surfing   M
# 1398  03-Jan-2012  2012.0  Unprovoked     AUSTRALIA               Surfing   M
# 1399  02-Jan-2012  2012.0  Unprovoked     AUSTRALIA          Spearfishing   M
#
# ...

# %%
df_top_5_recent= df_past_years.Country.value_counts().reset_index().head()
df_top_5_recent
# Out:
#           index  Country
# 0           USA      649
# 1     AUSTRALIA      296
# 2  SOUTH AFRICA       58
# 3       BAHAMAS       48
# 4   NEW ZEALAND       25

# %%
df_top_5_recent = df_top_5_recent.rename(columns={'index': 'Country', 'Country': 'Total'})
df_top_5_recent
# Out:
#         Country  Total
# 0           USA    649
# 1     AUSTRALIA    296
# 2  SOUTH AFRICA     58
# 3       BAHAMAS     48
# 4   NEW ZEALAND     25

# %%
# TOP 5 COUNTRIES IN RECENT 10 YEARS FATAL AND NON FATAL
sns.barplot(x='Country', y="Total", data=df_top_5_recent)
# Out:
# <Axes: xlabel='Country', ylabel='Total'>

# %%
df_past_50_years= df[df['Year'].between(2001.0,2011.0)][['Date','Year','Type', 'Country', 'Activity','Sex','Age','Injury']]
df_past_50_years
# Out:
#                        Date    Year        Type      Country  Activity  Sex  \
# 1400            31-Dec-2011  2011.0  Unprovoked          USA       NaN    M
# 1401   Reported 26-Dec-2011  2011.0     Invalid      ANTIGUA  Swimming    M
# 1402            25-Dec-2011  2011.0  Unprovoked      ECUADOR   Surfing    M
# 1403            23-Dec-2011  2011.0  Unprovoked          USA   Surfing    M
# 1404            21-Dec-2011  2011.0    Provoked          USA  Canoeing    M
# ...                     ...     ...         ...          ...       ...  ...
# 2547  Reported  24-Jan-2001  2001.0  Watercraft    AUSTRALIA  Kayaking    M
# 2548            24-Jan-2001  2001.0  Unprovoked         CUBA  Swimming    F
# 2549            21-Jan-2001  2001.0  Watercraft    AUSTRALIA   Fishing  NaN
# 2550            09-Jan-2001  2001.0  Unprovoked          USA   Surfing    M
# 2551            06-Jan-2001  2001.0  Watercraft  NEW ZEALAND  Kayaking    M
#
# ...

# %%
df_top_50_years= df_past_50_years.Country.value_counts().reset_index().head()
df_top_50_years
# Out:
#           index  Country
# 0           USA      560
# 1     AUSTRALIA      192
# 2  SOUTH AFRICA       88
# 3        BRAZIL       41
# 4   NEW ZEALAND       28

# %%
df_top_50_years_renamed = df_top_50_years.rename(columns={'index': 'Country', 'Country': 'Total'})
df_top_50_years_renamed
# Out:
#         Country  Total
# 0           USA    560
# 1     AUSTRALIA    192
# 2  SOUTH AFRICA     88
# 3        BRAZIL     41
# 4   NEW ZEALAND     28

# %%
# TOP 5 COUNTRIES IN PRIOR PRIOR 10 YEARS FATAL AND NON FATAL
sns.barplot(x='Country', y="Total", data=df_top_50_years_renamed )
# Out:
# <Axes: xlabel='Country', ylabel='Total'>

# %%
df_past_50_years.Country.value_counts()
# Out:
# USA              560
# AUSTRALIA        192
# SOUTH AFRICA      88
# BRAZIL            41
# NEW ZEALAND       28
#                 ...
# SOMALIA            1
# ANTIGUA            1
# MALTA              1
# SAMOA              1
# CARIBBEAN SEA      1
# Name: Country, Length: 71, dtype: int64

# %%
df_past_years_fatal= df_past_years[df_past_years['Injury'].str.contains("FATAL")]
df_past_years_fatal
# Out:
#              Date    Year        Type       Country       Activity Sex  Age  \
# 101   25-Sep-2022  2022.0  Unprovoked  SOUTH AFRICA       Swimming   F   39
# 103   06-Sep-2022  2022.0  Unprovoked       BAHAMAS     Snorkeling   F   58
# 124   04-Jul-2022  2022.0  Unprovoked         JAPAN     Snorkeling   M   60
# 128   01-Jul-2022  2022.0  Unprovoked         EGYPT     Snorkeling   F  40s
# 129   01-Jul-2022  2022.0  Unprovoked         EGYPT       Swimming   F   68
# ...           ...     ...         ...           ...            ...  ..  ...
# 1333  23-Jul-2012  2012.0  Unprovoked       REUNION        Surfing   M   22
# 1336  14-Jul-2012  2012.0  Unprovoked     AUSTRALIA        Surfing   M   24
# 1370  19-Apr-2012  2012.0  Unprovoked  SOUTH AFRICA  Body boarding   M   20
# 1374  31-Mar-2012  2012.0  Unprovoked     AUSTRALIA   Scuba diving   M   33
# 1396  15-Jan-2012  2012.0  Unprovoked  SOUTH AFRICA       Swimming   M   25
#
#      Injury
# 101   FATAL
# 103   FATAL
# 124   FATAL
# ...

# %%
df_past_50_years_fatal= df_past_50_years[df_past_50_years['Injury'].str.contains("FATAL")]
df_past_50_years_fatal
# Out:
#              Date    Year        Type    Country  \
# 1421  22-Oct-2011  2011.0  Unprovoked  AUSTRALIA
# 1426  09-Oct-2011  2011.0  Unprovoked  AUSTRALIA
# 1436  19-Sep-2011  2011.0  Unprovoked    REUNION
# 1437  17-Sep-2011  2011.0  Unprovoked      KENYA
# 1442  04-Sep-2011  2011.0  Unprovoked  AUSTRALIA
# ...           ...     ...         ...        ...
# 2470  16-Sep-2001  2001.0     Invalid        USA
# 2477  03-Sep-2001  2001.0  Unprovoked        USA
# 2480  01-Sep-2001  2001.0  Unprovoked        USA
# 2521     May-2001  2001.0  Unprovoked       FIJI
# 2542  03-Mar-2001  2001.0  Unprovoked     BRAZIL
#
#                               Activity Sex  Age  \
# 1421                            Diving   M   32
# 1426                          Swimming   M   64
# 1436                     Body boarding   M   38
# 1437                          Swimming   M   17
# 1442                     Body boarding   M   21
# ...                                ...  ..  ...
# ...

# %%
df_past_years_fatal.Country.value_counts()
# Out:
# AUSTRALIA           28
# SOUTH AFRICA        11
# USA                 10
# NEW CALEDONIA        6
# REUNION              6
# BRAZIL               5
# EGYPT                4
# MEXICO               4
# JAMAICA              3
# NEW ZEALAND          2
# BAHAMAS              2
# REUNION ISLAND       2
# MAURITIUS            1
# DIEGO GARCIA         1
# ITALY                1
# MOZAMBIQUE           1
# ARUBA                1
# Fiji                 1
# PAPUA NEW GUINEA     1
# CUBA                 1
# LIBYA                1
# COSTA RICA           1
# ST MARTIN            1
# COLUMBIA             1
# JAPAN                1
# GUAM                 1
# Name: Country, dtype: int64

# %%
df_past_years_fatal_top_5= df_past_years_fatal.Country.value_counts().reset_index().head()
df_past_years_fatal_top_5
# Out:
#            index  Country
# 0      AUSTRALIA       28
# 1   SOUTH AFRICA       11
# 2            USA       10
# 3  NEW CALEDONIA        6
# 4        REUNION        6

# %%
df_past_years_fatal_top_5_renamed = df_past_years_fatal_top_5.rename(columns={'index': 'Country', 'Country': 'Total'})
df_past_years_fatal_top_5_renamed
# Out:
#          Country  Total
# 0      AUSTRALIA     28
# 1   SOUTH AFRICA     11
# 2            USA     10
# 3  NEW CALEDONIA      6
# 4        REUNION      6

# %%
# TOP 5 COUNTRIES IN RECENT YEARS FATAL 
sns.barplot(x='Country', y="Total", data=df_past_years_fatal_top_5_renamed  )
# Out:
# <Axes: xlabel='Country', ylabel='Total'>

# %%
df_past_50_years_fatal.Country.value_counts()
# Out:
# AUSTRALIA               60
# USA                     51
# SOUTH AFRICA            46
# BRAZIL                  27
# PAPUA NEW GUINEA        21
# REUNION                 20
# MEXICO                  20
# HONG KONG               13
# FIJI                    12
# NEW CALEDONIA           10
# MOZAMBIQUE              10
# NEW ZEALAND              8
# VANUATU                  7
# EGYPT                    5
# PHILIPPINES              5
# SOUTH KOREA              5
# TANZANIA                 5
# CROATIA                  5
# NEW BRITAIN              4
# JAPAN                    4
# SOLOMON ISLANDS          4
# SOMALIA                  4
# OKINAWA                  4
# BAHAMAS                  4
# THAILAND                 3
# KENYA                    3
# PANAMA                   3
# GRENADA                  3
# ITALY                    3
# COSTA RICA               3
# TAIWAN                   3
# CHILE                    3
# VENEZUELA                2
# INDONESIA                2
# ...

# %%
df_top_50_years_top_5_fatal= df_past_50_years_fatal.Country.value_counts().reset_index().head()
df_top_50_years_top_5_fatal
# Out:
#               index  Country
# 0         AUSTRALIA       60
# 1               USA       51
# 2      SOUTH AFRICA       46
# 3            BRAZIL       27
# 4  PAPUA NEW GUINEA       21

# %%
df_top_50_years_top_5_fatal_renamed = df_top_50_years_top_5_fatal.rename(columns={'index': 'Country', 'Country': 'Total'})
df_top_50_years_top_5_fatal_renamed
# Out:
#             Country  Total
# 0         AUSTRALIA     60
# 1               USA     51
# 2      SOUTH AFRICA     46
# 3            BRAZIL     27
# 4  PAPUA NEW GUINEA     21

# %%
# TOP 5 COUNTRIES IN RECENT YEARS FATAL 
sns.barplot(x='Country', y="Total", data=df_top_50_years_top_5_fatal_renamed   )
# Out:
# <Axes: xlabel='Country', ylabel='Total'>
